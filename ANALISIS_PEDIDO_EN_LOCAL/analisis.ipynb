# %%
import pandas as pd 
import numpy as np

# %%
dfcsv = pd.read_csv('survey_lung_cancer.csv', delimiter=',')
dfcsv
#fumador SI = 2, NO = 1
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0        M   69        1               2        2              1
# 1        M   74        2               1        1              1
# 2        F   59        1               1        1              2
# 3        M   63        2               2        2              1
# 4        F   63        1               2        1              1
# ..     ...  ...      ...             ...      ...            ...
# 304      F   56        1               1        1              2
# 305      M   70        2               1        1              1
# 306      M   58        2               1        1              1
# 307      M   67        2               1        2              1
# 308      M   62        1               1        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0                  1         2         1         2                  2
# ...

# %%
#cuántos casos de cáncer existen en función de si los individuos son fumadores o no
t = dfcsv.groupby(['SMOKING'])
analisis = t.count()
print(analisis)
# Out:
#          GENDER  AGE  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  CHRONIC DISEASE  \
# SMOKING
# 1           135  135             135      135            135              135
# 2           174  174             174      174            174              174
#
#          FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  COUGHING  \
# SMOKING
# 1             135       135       135                135       135
# 2             174       174       174                174       174
#
#          SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN  LUNG_CANCER
# SMOKING
# 1                        135                    135         135          135
# 2                        174                    174         174          174
